# %% [markdown]
# # *Computing DBSCAN clustering on similarity matrices with parameter combinations*

# %% [markdown]
# **Author: Lucía Prieto Santamaría **(lucia.prieto.santamaria@alumnos.upm.es)
#
# This notebook was written to develop complete DBSCAN clustering analysis on similarity matrices stored in csv files. It explores the values of *Silhouette* given different values of Eps (epsilon) and MinPts (ms).

# %%
# Import of the needed libraries
import csv # Module to get the data from the similarity matrices stored in csv files
import numpy as np # Library needed to structure the data before implementing the algorithm
from sklearn.cluster import DBSCAN # Extension of scikit-learn that implements the algorithm DBSCAN
from sklearn import metrics # Extension of scikit-learn that will be used to compute silhouette coefficient

# %%
# VARIABLES DECLARATION

# We need to specify here the total number of diseases in the subset we are working with
number_of_diseases = 3671

# Folder and group name to identify the correct directory
# IMPORTANT!!!! THE FOLDER NEEDS TO BE PREVIOUSLY CREATED BY THE USER
directory_name = 'weighted_score/wesco'

# Similarity metrics that 
sim_metrics = (
   'S_gen_cos',
   'S_gen_jaccard',
   'S_gen_dice',
   'S_prot_cos',
   'S_prot_jaccard',
   'S_prot_dice',
   'S_path_cos',
   'S_path_jaccard',
   'S_path_dice',
   'S_ppi_cos',
   'S_ppi_jaccard',
   'S_ppi_dice',
   'S_term_cos',
   'S_term_jaccard',
   'S_term_dice'
   )


# Eps (epsilon) is one of the parameters that have to be declared to DBSCAN. 
# We set the following values to explore them:
epsilons = (
        0.3,
        0.4,
        0.5,
        0.6,
        0.65,
        0.7,
        0.75,
        0.8,
        0.85,
        0.9,
        0.95,
        0.99
        )

# MinPts (ms) is the other parameter for DBSCAN. We will set the following values 
ms_values = (
            2, 
            3, 
            5, 
            30)

# Dictionaries that as keys will contain a list of the combinations of the corresponding value of Eps, MinPts and the
# specific similarity metric.
n_clusters = {} # As values contains the number of clusters generated for the combination of the key's parameters
silh_coef = {} # As values contains the value of Silhouette computed for the combination of the key's parameters

# %%
# Getting the list of diseases we are going to work with

file_name = 'excels/' + directory_name + str(sim_metrics[0]) + '.csv'

with open(file_name) as f:
    reader = csv.reader(f, delimiter = ",")
    diseases = next(reader)

diseases.pop(0)
    
f.close()

# %%
# PERFORMING CLUSTERING ON SIMILARITY MATRICES

columns = tuple(range(1, number_of_diseases + 1)) # Columns to get from the similarity matrix excel file


for metric in sim_metrics:
    
    distance = str(metric[2:len(metric)])
    print ("\n\nWorking on %s" %metric)
    
    file_name = 'excels/' + directory_name + str(metric) + '.csv'
    my_data = np.genfromtxt(file_name, delimiter= ",", skip_header = 1, usecols = columns)
    
    X = 1 - my_data # Convert similarity measure into distance
    
    for ms in ms_values:    
        
        print ("\n----> MinPts %s" %ms)
        
        for epsilon in epsilons:   
    
            labels = DBSCAN(eps=epsilon, min_samples=ms, metric='precomputed').fit_predict(X)
        
            if not 0 in labels:
                n_clusters[epsilon, ms, metric] = 0
                n_noise = list(labels).count(-1)
                silh_coef[epsilon, ms, metric] = -1
         
         
            else:
                # Number of clusters in labels, ignoring noise if present.
                n_clusters[epsilon, ms, metric] =  len(set(labels)) - (1 if -1 in labels else 0)
                n_noise = list(labels).count(-1)
                print("\tNumber of clusters: ", n_clusters[epsilon, ms, metric])
                print("\tNumber of outliers: ", n_noise)
        
                try:
                    silh_coef[epsilon, ms, metric] = metrics.silhouette_score(X, labels, metric='precomputed')
                    print("\t\t",silh_coef[epsilon, ms, metric])
                except ValueError:
                    silh_coef[epsilon, ms, metric] = -1
# Out:
# Working on S_gen_cos
#
# ----> MinPts 2
# 	Number of clusters:  437
# 	Number of outliers:  2164
# 		 0.18383059513673353
# 	Number of clusters:  463
# 	Number of outliers:  1898
# 		 0.2012604278659193
# 	Number of clusters:  388
# 	Number of outliers:  1516
# 		 0.1547509991121918
# 	Number of clusters:  256
# 	Number of outliers:  1142
# 		 0.07638056053471447
# 	Number of clusters:  180
# 	Number of outliers:  957
# 		 0.05148726401344943
# 	Number of clusters:  118
# 	Number of outliers:  787
# 		 0.03573924105587854
# 	Number of clusters:  72
# 	Number of outliers:  654
# 		 0.029838211246256255
# 	Number of clusters:  45
# 	Number of outliers:  562
# 		 0.024186198482233873
# 	Number of clusters:  28
# 	Number of outliers:  496
# 		 0.01598671643276528
# 	Number of clusters:  17
# 	Number of outliers:  423
# 		 0.011521357634261813
# 	Number of clusters:  11
# 	Number of outliers:  385
# 		 0.008763817911931315
# 	Number of clusters:  6
# 	Number of outliers:  355
# 		 0.005331107071604288
#
# ----> MinPts 3
# 	Number of clusters:  201
# 	Number of outliers:  2636
# 		 0.10071431881009969
# 	Number of clusters:  217
# 	Number of outliers:  2390
# 		 0.11937596122497696
# 	Number of clusters:  200
# 	Number of outliers:  1892
# 		 0.09713521395061288
# 	Number of clusters:  116
# 	Number of outliers:  1422
# 		 0.04300355590627167
# 	Number of clusters:  68
# 	Number of outliers:  1181
# 		 0.02860940448942643
# 	Number of clusters:  50
# 	Number of outliers:  923
# 		 0.015581582253719452
# 	Number of clusters:  29
# 	Number of outliers:  740
# 		 0.01564459822717942
# 	Number of clusters:  17
# 	Number of outliers:  618
# 		 0.012827199533428181
# 	Number of clusters:  8
# 	Number of outliers:  536
# 		 0.008212938005548317
# 	Number of clusters:  6
# 	Number of outliers:  445
# 		 0.006866526406525359
# 	Number of clusters:  4
# 	Number of outliers:  399
# 		 0.005684830050118744
# 	Number of clusters:  1
# 	Number of outliers:  365
# 		 0.003298188944979113
#
# ----> MinPts 5
# 	Number of clusters:  60
# 	Number of outliers:  3161
# 		 0.025886311049522343
# 	Number of clusters:  79
# 	Number of outliers:  2929
# 		 0.049254483381216664
# 	Number of clusters:  92
# 	Number of outliers:  2435
# 		 0.05598759266433996
# 	Number of clusters:  61
# 	Number of outliers:  1794
# 		 0.022868511512970032
# 	Number of clusters:  37
# 	Number of outliers:  1454
# 		 0.014133455616088086
# 	Number of clusters:  21
# 	Number of outliers:  1149
# 		 0.00916749361211772
# 	Number of clusters:  11
# 	Number of outliers:  890
# 		 0.007790022028501578
# 	Number of clusters:  4
# 	Number of outliers:  699
# 		 0.005270151033409132
# 	Number of clusters:  2
# 	Number of outliers:  567
# 		 0.004901729955099402
# 	Number of clusters:  2
# 	Number of outliers:  468
# 		 0.004856488692676417
# 	Number of clusters:  3
# 	Number of outliers:  408
# 		 0.005358314325507782
# 	Number of clusters:  1
# 	Number of outliers:  370
# 		 0.003299389762065497
#
# ----> MinPts 30
# 	Number of clusters:  1
# 	Number of outliers:  3627
# 		 -0.0013631379258633284
# 	Number of clusters:  1
# 	Number of outliers:  3531
# 		 0.0016596059268524795
# 	Number of clusters:  1
# 	Number of outliers:  3401
# 		 0.0044923068307547095
# 	Number of clusters:  1
# 	Number of outliers:  3229
# 		 0.0049658802034466005
# 	Number of clusters:  1
# 	Number of outliers:  3022
# 		 0.005224202779399725
# 	Number of clusters:  2
# 	Number of outliers:  2642
# 		 0.00533175528061977
# 	Number of clusters:  4
# 	Number of outliers:  1874
# 		 0.003083861803337505
# 	Number of clusters:  2
# 	Number of outliers:  1064
# 		 0.003322945003605987
# 	Number of clusters:  1
# 	Number of outliers:  607
# 		 0.003494097924269061
# 	Number of clusters:  1
# 	Number of outliers:  473
# 		 0.0034078059181733736
# 	Number of clusters:  1
# 	Number of outliers:  403
# 		 0.0033439970816587644
#
#
# Working on S_gen_jaccard
#
# ----> MinPts 2
# 	Number of clusters:  213
# 	Number of outliers:  3142
# 		 0.06980995585398742
# 	Number of clusters:  260
# 	Number of outliers:  3004
# 		 0.08544574388654975
# 	Number of clusters:  323
# 	Number of outliers:  2763
# 		 0.1096567909035019
# 	Number of clusters:  389
# 	Number of outliers:  2477
# 		 0.12953127637014825
# 	Number of clusters:  421
# 	Number of outliers:  2282
# 		 0.13732970353116827
# 	Number of clusters:  436
# 	Number of outliers:  2019
# 		 0.13446837443156398
# 	Number of clusters:  411
# 	Number of outliers:  1744
# 		 0.11643806263310597
# 	Number of clusters:  327
# 	Number of outliers:  1467
# 		 0.08258985390678311
# 	Number of clusters:  215
# 	Number of outliers:  1139
# 		 0.04882330148691408
# 	Number of clusters:  115
# 	Number of outliers:  864
# 		 0.029199967694094754
# 	Number of clusters:  54
# 	Number of outliers:  650
# 		 0.015917805789680724
# 	Number of clusters:  20
# 	Number of outliers:  486
# 		 0.006983229981905726
#
# ----> MinPts 3
# 	Number of clusters:  64
# 	Number of outliers:  3440
# 		 0.021132883282693204
# 	Number of clusters:  78
# 	Number of outliers:  3368
# 		 0.032007974041751194
# 	Number of clusters:  116
# 	Number of outliers:  3177
# 		 0.05069605477597658
# 	Number of clusters:  156
# 	Number of outliers:  2943
# 		 0.06165500394102602
# 	Number of clusters:  176
# 	Number of outliers:  2772
# 		 0.07045758170743054
# 	Number of clusters:  198
# 	Number of outliers:  2495
# 		 0.07389581707661988
# 	Number of clusters:  187
# 	Number of outliers:  2192
# 		 0.06429263864100321
# 	Number of clusters:  131
# 	Number of outliers:  1859
# 		 0.04308557680865845
# 	Number of clusters:  74
# 	Number of outliers:  1421
# 		 0.019262691985769263
# 	Number of clusters:  36
# 	Number of outliers:  1022
# 		 0.011495669174911533
# 	Number of clusters:  11
# 	Number of outliers:  736
# 		 0.005058084098683099
# 	Number of clusters:  4
# 	Number of outliers:  518
# 		 0.0023935460348795557
#
# ----> MinPts 5
# 	Number of clusters:  9
# 	Number of outliers:  3624
# 		 -0.0023922173829372347
# 	Number of clusters:  14
# 	Number of outliers:  3585
# 		 0.002181527150850337
# 	Number of clusters:  28
# 	Number of outliers:  3484
# 		 0.012991979389477814
# 	Number of clusters:  44
# 	Number of outliers:  3354
# 		 0.024046305789621376
# 	Number of clusters:  53
# 	Number of outliers:  3245
# 		 0.02876535242780382
# 	Number of clusters:  68
# 	Number of outliers:  3048
# 		 0.0313487370866734
# 	Number of clusters:  88
# 	Number of outliers:  2739
# 		 0.03553930278522357
# 	Number of clusters:  82
# 	Number of outliers:  2309
# 		 0.027682625554150166
# 	Number of clusters:  32
# 	Number of outliers:  1791
# 		 0.010070355177328866
# 	Number of clusters:  12
# 	Number of outliers:  1235
# 		 0.0031456575266689407
# 	Number of clusters:  4
# 	Number of outliers:  811
# 		 0.002275756550838764
# 	Number of clusters:  3
# 	Number of outliers:  531
# 		 0.0021798474415135193
#
# ----> MinPts 30
# 	Number of clusters:  1
# 	Number of outliers:  3638
# 		 -0.0006321392290171115
# 	Number of clusters:  2
# 	Number of outliers:  3545
# 		 0.0034399786529993874
# 	Number of clusters:  2
# 	Number of outliers:  3474
# 		 0.0038698099859946302
# 	Number of clusters:  2
# 	Number of outliers:  3127
# 		 0.0024118494662625366
# 	Number of clusters:  1
# 	Number of outliers:  1498
# 		 0.0010518050790154258
# 	Number of clusters:  1
# 	Number of outliers:  663
# 		 0.0008774703802442202
#
#
# Working on S_gen_dice
#
# ----> MinPts 2
# 	Number of clusters:  280
# 	Number of outliers:  2928
# 		 0.07463217836425776
# 	Number of clusters:  375
# 	Number of outliers:  2572
# 		 0.11928567531737838
# 	Number of clusters:  439
# 	Number of outliers:  2182
# 		 0.1538432177457326
# 	Number of clusters:  411
# 	Number of outliers:  1744
# 		 0.13478303106634235
# 	Number of clusters:  354
# 	Number of outliers:  1557
# 		 0.10927510033793038
# 	Number of clusters:  272
# 	Number of outliers:  1322
# 		 0.06754604495478374
# 	Number of clusters:  188
# 	Number of outliers:  1088
# 		 0.044919487501121486
# 	Number of clusters:  137
# 	Number of outliers:  922
# 		 0.037663850923310385
# 	Number of clusters:  78
# 	Number of outliers:  790
# 		 0.025931041149804022
# 	Number of clusters:  57
# 	Number of outliers:  660
# 		 0.01963475444594491
# 	Number of clusters:  32
# 	Number of outliers:  543
# 		 0.014233759984123004
# 	Number of clusters:  14
# 	Number of outliers:  448
# 		 0.006258844026250935
#
# ----> MinPts 3
# 	Number of clusters:  84
# 	Number of outliers:  3320
# 		 0.027823417149710164
# 	Number of clusters:  140
# 	Number of outliers:  3042
# 		 0.05453980913432853
# 	Number of clusters:  187
# 	Number of outliers:  2686
# 		 0.07909953245539608
# 	Number of clusters:  187
# 	Number of outliers:  2192
# 		 0.07658185288769939
# 	Number of clusters:  156
# 	Number of outliers:  1953
# 		 0.05932883174783979
# 	Number of clusters:  96
# 	Number of outliers:  1674
# 		 0.03379742287122019
# 	Number of clusters:  59
# 	Number of outliers:  1346
# 		 0.016814083756859124
# 	Number of clusters:  46
# 	Number of outliers:  1104
# 		 0.016463142967514364
# 	Number of clusters:  19
# 	Number of outliers:  908
# 		 0.00972486661778741
# 	Number of clusters:  11
# 	Number of outliers:  752
# 		 0.0064416196300505196
# 	Number of clusters:  8
# 	Number of outliers:  591
# 		 0.00540323361112773
# 	Number of clusters:  3
# 	Number of outliers:  470
# 		 0.002735169944638096
#
# ----> MinPts 5
# 	Number of clusters:  19
# 	Number of outliers:  3541
# 		 0.0036288447850918127
# 	Number of clusters:  32
# 	Number of outliers:  3427
# 		 0.015546867350947225
# 	Number of clusters:  61
# 	Number of outliers:  3186
# 		 0.03173841814450823
# 	Number of clusters:  88
# 	Number of outliers:  2739
# 		 0.04186393333604027
# 	Number of clusters:  83
# 	Number of outliers:  2442
# 		 0.03382638144208217
# 	Number of clusters:  59
# 	Number of outliers:  2052
# 		 0.02264537596648071
# 	Number of clusters:  31
# 	Number of outliers:  1679
# 		 0.010868637633402298
# 	Number of clusters:  20
# 	Number of outliers:  1347
# 		 0.007806665428126594
# 	Number of clusters:  6
# 	Number of outliers:  1050
# 		 0.004311893517987833
# 	Number of clusters:  4
# 	Number of outliers:  826
# 		 0.0032544296329127627
# 	Number of clusters:  6
# 	Number of outliers:  631
# 		 0.0037044937283140004
# 	Number of clusters:  2
# 	Number of outliers:  479
# 		 0.002504772584665268
#
# ----> MinPts 30
# 	Number of clusters:  1
# 	Number of outliers:  3638
# 		 -0.001807563166301856
# 	Number of clusters:  1
# 	Number of outliers:  3579
# 		 0.002716333618756552
# 	Number of clusters:  2
# 	Number of outliers:  3515
# 		 0.0052210355541661545
# 	Number of clusters:  2
# 	Number of outliers:  3457
# 		 0.0057629605709723685
# 	Number of clusters:  2
# 	Number of outliers:  3280
# 		 0.003981333413374159
# 	Number of clusters:  4
# 	Number of outliers:  2729
# 		 0.004259247811735575
# 	Number of clusters:  2
# 	Number of outliers:  1596
# 		 0.0019542323937096076
# 	Number of clusters:  1
# 	Number of outliers:  914
# 		 0.0015749985338820334
# 	Number of clusters:  1
# 	Number of outliers:  575
# 		 0.001448842162280764
#
#
# Working on S_prot_cos
#
# ----> MinPts 2
# 	Number of clusters:  439
# 	Number of outliers:  2055
# 		 0.2045936732479515
# 	Number of clusters:  460
# 	Number of outliers:  1801
# 		 0.22170008138106165
# 	Number of clusters:  379
# 	Number of outliers:  1426
# 		 0.14975024753142496
# 	Number of clusters:  249
# 	Number of outliers:  1071
# 		 0.07112543405364251
# 	Number of clusters:  181
# 	Number of outliers:  898
# 		 0.05238530467479984
# 	Number of clusters:  124
# 	Number of outliers:  747
# 		 0.03306567505458879
# 	Number of clusters:  79
# 	Number of outliers:  630
# 		 0.03252595540233854
# 	Number of clusters:  50
# 	Number of outliers:  536
# 		 0.027065615395041223
# 	Number of clusters:  30
# 	Number of outliers:  474
# 		 0.017860120493830824
# 	Number of clusters:  19
# 	Number of outliers:  411
# 		 0.012971109914433317
# 	Number of clusters:  12
# 	Number of outliers:  371
# 		 0.009696988165648053
# 	Number of clusters:  7
# 	Number of outliers:  345
# 		 0.006257458627498712
#
# ----> MinPts 3
# 	Number of clusters:  203
# 	Number of outliers:  2527
# 		 0.12291597130427762
# 	Number of clusters:  224
# 	Number of outliers:  2273
# 		 0.14353893367387835
# 	Number of clusters:  193
# 	Number of outliers:  1798
# 		 0.09943535468002135
# 	Number of clusters:  110
# 	Number of outliers:  1349
# 		 0.04366867863359763
# 	Number of clusters:  69
# 	Number of outliers:  1122
# 		 0.03175530430840141
# 	Number of clusters:  52
# 	Number of outliers:  891
# 		 0.018866112639519622
# 	Number of clusters:  30
# 	Number of outliers:  728
# 		 0.0167331908966357
# 	Number of clusters:  18
# 	Number of outliers:  600
# 		 0.014595181530187178
# 	Number of clusters:  8
# 	Number of outliers:  518
# 		 0.008856837389703241
# 	Number of clusters:  6
# 	Number of outliers:  437
# 		 0.0074992860392811035
# 	Number of clusters:  4
# 	Number of outliers:  387
# 		 0.006305082090845347
# 	Number of clusters:  1
# 	Number of outliers:  357
# 		 0.003911906499762331
#
# ----> MinPts 5
# 	Number of clusters:  62
# 	Number of outliers:  3047
# 		 0.04365466129137223
# 	Number of clusters:  81
# 	Number of outliers:  2823
# 		 0.06672494341692474
# 	Number of clusters:  94
# 	Number of outliers:  2336
# 		 0.06471975314347692
# 	Number of clusters:  59
# 	Number of outliers:  1720
# 		 0.02205082998092955
# 	Number of clusters:  35
# 	Number of outliers:  1405
# 		 0.015497177575768245
# 	Number of clusters:  19
# 	Number of outliers:  1129
# 		 0.009034795841900686
# 	Number of clusters:  12
# 	Number of outliers:  876
# 		 0.009810565356303114
# 	Number of clusters:  5
# 	Number of outliers:  690
# 		 0.006963069187188404
# 	Number of clusters:  2
# 	Number of outliers:  550
# 		 0.00554395790799686
# 	Number of clusters:  2
# 	Number of outliers:  461
# 		 0.0054816768378321435
# 	Number of clusters:  3
# 	Number of outliers:  396
# 		 0.005979656403181931
# 	Number of clusters:  1
# 	Number of outliers:  362
# 		 0.003913951733995726
#
# ----> MinPts 30
# 	Number of clusters:  2
# 	Number of outliers:  3544
# 		 0.012315299974102339
# 	Number of clusters:  1
# 	Number of outliers:  3512
# 		 0.01270289586614779
# 	Number of clusters:  2
# 	Number of outliers:  3457
# 		 0.00941225638784043
# 	Number of clusters:  1
# 	Number of outliers:  3332
# 		 0.01081560577300365
# 	Number of clusters:  1
# 	Number of outliers:  3209
# 		 0.009927145200316106
# 	Number of clusters:  1
# 	Number of outliers:  2976
# 		 0.008361931040845112
# 	Number of clusters:  2
# 	Number of outliers:  2638
# 		 0.007443151725350393
# 	Number of clusters:  3
# 	Number of outliers:  1902
# 		 0.005372942732914943
# 	Number of clusters:  3
# 	Number of outliers:  1040
# 		 0.004126547412111404
# 	Number of clusters:  1
# 	Number of outliers:  604
# 		 0.004136779466703107
# 	Number of clusters:  1
# 	Number of outliers:  460
# 		 0.004034412994640554
# 	Number of clusters:  1
# 	Number of outliers:  392
# 		 0.003962201086309805
#
#
# Working on S_prot_jaccard
#
# ----> MinPts 2
# 	Number of clusters:  226
# 	Number of outliers:  3051
# 		 0.08013241132159152
# 	Number of clusters:  267
# 	Number of outliers:  2891
# 		 0.09869336577977796
# 	Number of clusters:  332
# 	Number of outliers:  2649
# 		 0.12252638691231513
# 	Number of clusters:  396
# 	Number of outliers:  2371
# 		 0.1427880060798326
# 	Number of clusters:  428
# 	Number of outliers:  2183
# 		 0.1483571520589535
# 	Number of clusters:  439
# 	Number of outliers:  1922
# 		 0.14245902928823387
# 	Number of clusters:  400
# 	Number of outliers:  1655
# 		 0.11986068229248505
# 	Number of clusters:  317
# 	Number of outliers:  1383
# 		 0.08181812266744909
# 	Number of clusters:  216
# 	Number of outliers:  1097
# 		 0.051476997176061676
# 	Number of clusters:  118
# 	Number of outliers:  833
# 		 0.03251081815425143
# 	Number of clusters:  57
# 	Number of outliers:  635
# 		 0.017072386450019347
# 	Number of clusters:  21
# 	Number of outliers:  476
# 		 0.007491524773031793
#
# ----> MinPts 3
# 	Number of clusters:  69
# 	Number of outliers:  3365
# 		 0.02653193311161586
# 	Number of clusters:  85
# 	Number of outliers:  3255
# 		 0.042253548212705994
# 	Number of clusters:  120
# 	Number of outliers:  3073
# 		 0.05852016689948228
# 	Number of clusters:  156
# 	Number of outliers:  2851
# 		 0.07245687974244525
# 	Number of clusters:  176
# 	Number of outliers:  2687
# 		 0.07742949357839111
# 	Number of clusters:  196
# 	Number of outliers:  2408
# 		 0.07920863626381341
# 	Number of clusters:  178
# 	Number of outliers:  2099
# 		 0.0660944680873724
# 	Number of clusters:  126
# 	Number of outliers:  1765
# 		 0.04223467147560249
# 	Number of clusters:  75
# 	Number of outliers:  1379
# 		 0.020576338494944387
# 	Number of clusters:  35
# 	Number of outliers:  999
# 		 0.013047168763566687
# 	Number of clusters:  11
# 	Number of outliers:  727
# 		 0.0051621408565909665
# 	Number of clusters:  5
# 	Number of outliers:  508
# 		 0.0027254024812886322
#
# ----> MinPts 5
# 	Number of clusters:  13
# 	Number of outliers:  3556
# 		 0.0009842906534186916
# 	Number of clusters:  19
# 	Number of outliers:  3481
# 		 0.010395991428768427
# 	Number of clusters:  32
# 	Number of outliers:  3378
# 		 0.019995861833968023
# 	Number of clusters:  46
# 	Number of outliers:  3246
# 		 0.03136043664167774
# 	Number of clusters:  56
# 	Number of outliers:  3139
# 		 0.0394278337800428
# 	Number of clusters:  72
# 	Number of outliers:  2941
# 		 0.04171372813320445
# 	Number of clusters:  90
# 	Number of outliers:  2633
# 		 0.04229999186482341
# 	Number of clusters:  75
# 	Number of outliers:  2216
# 		 0.027470055323940548
# 	Number of clusters:  33
# 	Number of outliers:  1735
# 		 0.012163711979011576
# 	Number of clusters:  12
# 	Number of outliers:  1202
# 		 0.004890561766318865
# 	Number of clusters:  4
# 	Number of outliers:  798
# 		 0.0024411080538182797
# 	Number of clusters:  3
# 	Number of outliers:  527
# 		 0.0023348731030062237
#
# ----> MinPts 30
# 	Number of clusters:  1
# 	Number of outliers:  3626
# 		 0.00262132026004639
# 	Number of clusters:  1
# 	Number of outliers:  3580
# 		 0.004878800108288286
# 	Number of clusters:  1
# 	Number of outliers:  3566
# 		 0.005175357318626855
# 	Number of clusters:  1
# 	Number of outliers:  3562
# 		 0.005239530333684847
# 	Number of clusters:  2
# 	Number of outliers:  3511
# 		 0.005553087115878228
# 	Number of clusters:  3
# 	Number of outliers:  3393
# 		 0.006889323198050415
# 	Number of clusters:  1
# 	Number of outliers:  3046
# 		 0.0021621123080209437
# 	Number of clusters:  1
# 	Number of outliers:  1545
# 		 0.0012925162484424982
# 	Number of clusters:  1
# 	Number of outliers:  658
# 		 0.00103774260126057
#
#
# Working on S_prot_dice
#
# ----> MinPts 2
# 	Number of clusters:  286
# 	Number of outliers:  2816
# 		 0.09317481509378503
# 	Number of clusters:  381
# 	Number of outliers:  2460
# 		 0.13915777344755667
# 	Number of clusters:  448
# 	Number of outliers:  2079
# 		 0.16813683586511935
# 	Number of clusters:  400
# 	Number of outliers:  1655
# 		 0.13872065132992037
# 	Number of clusters:  351
# 	Number of outliers:  1472
# 		 0.10828109526111411
# 	Number of clusters:  263
# 	Number of outliers:  1261
# 		 0.0714610885288181
# 	Number of clusters:  195
# 	Number of outliers:  1050
# 		 0.04844864703696296
# 	Number of clusters:  136
# 	Number of outliers:  892
# 		 0.041093406929057094
# 	Number of clusters:  83
# 	Number of outliers:  764
# 		 0.02776652046623437
# 	Number of clusters:  60
# 	Number of outliers:  647
# 		 0.021128485201974266
# 	Number of clusters:  32
# 	Number of outliers:  529
# 		 0.014427002547289338
# 	Number of clusters:  15
# 	Number of outliers:  438
# 		 0.006819003380444206
#
# ----> MinPts 3
# 	Number of clusters:  89
# 	Number of outliers:  3210
# 		 0.03882113909582638
# 	Number of clusters:  143
# 	Number of outliers:  2936
# 		 0.06657607954408443
# 	Number of clusters:  188
# 	Number of outliers:  2599
# 		 0.08867372607590929
# 	Number of clusters:  178
# 	Number of outliers:  2099
# 		 0.07906852062346473
# 	Number of clusters:  149
# 	Number of outliers:  1876
# 		 0.05865118129047372
# 	Number of clusters:  98
# 	Number of outliers:  1591
# 		 0.03515847627342639
# 	Number of clusters:  64
# 	Number of outliers:  1312
# 		 0.021081271675032414
# 	Number of clusters:  42
# 	Number of outliers:  1080
# 		 0.017171870564629158
# 	Number of clusters:  22
# 	Number of outliers:  886
# 		 0.010266967831792297
# 	Number of clusters:  11
# 	Number of outliers:  745
# 		 0.0066861757512675195
# 	Number of clusters:  9
# 	Number of outliers:  575
# 		 0.005887157169720864
# 	Number of clusters:  3
# 	Number of outliers:  462
# 		 0.002934121269046288
#
# ----> MinPts 5
# 	Number of clusters:  24
# 	Number of outliers:  3435
# 		 0.00841541873357772
# 	Number of clusters:  37
# 	Number of outliers:  3313
# 		 0.023311466056069968
# 	Number of clusters:  61
# 	Number of outliers:  3090
# 		 0.045232141405578005
# 	Number of clusters:  90
# 	Number of outliers:  2633
# 		 0.05094844521790894
# 	Number of clusters:  83
# 	Number of outliers:  2352
# 		 0.037618323213744316
# 	Number of clusters:  56
# 	Number of outliers:  1968
# 		 0.02196771074064393
# 	Number of clusters:  31
# 	Number of outliers:  1637
# 		 0.013317682956090275
# 	Number of clusters:  20
# 	Number of outliers:  1311
# 		 0.008077141055487723
# 	Number of clusters:  8
# 	Number of outliers:  1037
# 		 0.005794129432818098
# 	Number of clusters:  4
# 	Number of outliers:  818
# 		 0.003475997227624846
# 	Number of clusters:  5
# 	Number of outliers:  619
# 		 0.0036725864925961148
# 	Number of clusters:  2
# 	Number of outliers:  473
# 		 0.0027050478274595014
#
# ----> MinPts 30
# 	Number of clusters:  1
# 	Number of outliers:  3630
# 		 0.0019887204886534534
# 	Number of clusters:  1
# 	Number of outliers:  3580
# 		 0.006528204792181175
# 	Number of clusters:  1
# 	Number of outliers:  3562
# 		 0.007326456461959828
# 	Number of clusters:  2
# 	Number of outliers:  3516
# 		 0.007364502240091599
# 	Number of clusters:  3
# 	Number of outliers:  3431
# 		 0.009709647541203487
# 	Number of clusters:  3
# 	Number of outliers:  3369
# 		 0.009341763349502721
# 	Number of clusters:  1
# 	Number of outliers:  3187
# 		 0.003776206045279878
# 	Number of clusters:  3
# 	Number of outliers:  2657
# 		 0.002722055251919416
# 	Number of clusters:  2
# 	Number of outliers:  1631
# 		 0.0014010622022702429
# 	Number of clusters:  1
# 	Number of outliers:  918
# 		 0.001812770700954093
# 	Number of clusters:  1
# 	Number of outliers:  581
# 		 0.0016651470100205068
#
#
# Working on S_path_cos
#
# ----> MinPts 2
# 	Number of clusters:  111
# 	Number of outliers:  1200
# 		 -0.12424388832042028
# 	Number of clusters:  38
# 	Number of outliers:  968
# 		 -0.11842906228555453
# 	Number of clusters:  8
# 	Number of outliers:  838
# 		 0.006641667169802225
# 	Number of clusters:  3
# 	Number of outliers:  817
# 		 0.06156257267234631
# 	Number of clusters:  2
# 	Number of outliers:  817
# 		 0.06503390383570277
# 	Number of clusters:  2
# 	Number of outliers:  817
# 		 0.06503390383570277
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
#
# ----> MinPts 3
# 	Number of clusters:  76
# 	Number of outliers:  1270
# 		 -0.11604230829896262
# 	Number of clusters:  25
# 	Number of outliers:  994
# 		 -0.09730928858394655
# 	Number of clusters:  3
# 	Number of outliers:  848
# 		 0.06808151824388771
# 	Number of clusters:  1
# 	Number of outliers:  821
# 		 0.07343239197028253
# 	Number of clusters:  1
# 	Number of outliers:  819
# 		 0.07340240217689901
# 	Number of clusters:  1
# 	Number of outliers:  819
# 		 0.07340240217689901
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
#
# ----> MinPts 5
# 	Number of clusters:  44
# 	Number of outliers:  1424
# 		 -0.09906147985485254
# 	Number of clusters:  16
# 	Number of outliers:  1083
# 		 -0.03823006172407566
# 	Number of clusters:  1
# 	Number of outliers:  856
# 		 0.07112623688192066
# 	Number of clusters:  1
# 	Number of outliers:  821
# 		 0.07343239197028253
# 	Number of clusters:  1
# 	Number of outliers:  819
# 		 0.07340240217689901
# 	Number of clusters:  1
# 	Number of outliers:  819
# 		 0.07340240217689901
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
#
# ----> MinPts 30
# 	Number of clusters:  4
# 	Number of outliers:  2753
# 		 0.012729787269092295
# 	Number of clusters:  2
# 	Number of outliers:  2218
# 		 0.040040803693366635
# 	Number of clusters:  1
# 	Number of outliers:  1218
# 		 0.0657544380309584
# 	Number of clusters:  1
# 	Number of outliers:  838
# 		 0.0734409105015621
# 	Number of clusters:  1
# 	Number of outliers:  828
# 		 0.07359510708528828
# 	Number of clusters:  1
# 	Number of outliers:  820
# 		 0.07342662287795924
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.07336589613319991
#
#
# Working on S_path_jaccard
#
# ----> MinPts 2
# 	Number of clusters:  347
# 	Number of outliers:  2411
# 		 0.0837119587809754
# 	Number of clusters:  342
# 	Number of outliers:  2041
# 		 0.10388908746385218
# 	Number of clusters:  262
# 	Number of outliers:  1603
# 		 0.047191677200056896
# 	Number of clusters:  148
# 	Number of outliers:  1274
# 		 1.0296286869127216e-05
# 	Number of clusters:  98
# 	Number of outliers:  1106
# 		 -0.010833063122470952
# 	Number of clusters:  35
# 	Number of outliers:  950
# 		 -0.01569169311468265
# 	Number of clusters:  6
# 	Number of outliers:  876
# 		 0.01013164860183354
# 	Number of clusters:  3
# 	Number of outliers:  840
# 		 0.014199844743443152
# 	Number of clusters:  2
# 	Number of outliers:  825
# 		 0.01436251596515025
# 	Number of clusters:  1
# 	Number of outliers:  821
# 		 0.014843418564648384
# 	Number of clusters:  1
# 	Number of outliers:  818
# 		 0.014832260268751736
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.014822182208877637
#
# ----> MinPts 3
# 	Number of clusters:  179
# 	Number of outliers:  2747
# 		 0.018394109330483965
# 	Number of clusters:  181
# 	Number of outliers:  2363
# 		 0.05066989264628919
# 	Number of clusters:  148
# 	Number of outliers:  1831
# 		 0.02713373893200211
# 	Number of clusters:  85
# 	Number of outliers:  1400
# 		 0.002208127670620666
# 	Number of clusters:  49
# 	Number of outliers:  1204
# 		 0.003488593422734507
# 	Number of clusters:  20
# 	Number of outliers:  980
# 		 -0.006465205546472081
# 	Number of clusters:  1
# 	Number of outliers:  886
# 		 0.014472610257163059
# 	Number of clusters:  1
# 	Number of outliers:  844
# 		 0.01484191811030285
# 	Number of clusters:  1
# 	Number of outliers:  827
# 		 0.014869316949598704
# 	Number of clusters:  1
# 	Number of outliers:  821
# 		 0.014843418564648384
# 	Number of clusters:  1
# 	Number of outliers:  818
# 		 0.014832260268751736
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.014822182208877637
#
# ----> MinPts 5
# 	Number of clusters:  56
# 	Number of outliers:  3181
# 		 -0.04575135078406742
# 	Number of clusters:  80
# 	Number of outliers:  2750
# 		 0.004274501183780295
# 	Number of clusters:  74
# 	Number of outliers:  2183
# 		 0.01874515411046271
# 	Number of clusters:  45
# 	Number of outliers:  1658
# 		 0.009412356033728333
# 	Number of clusters:  28
# 	Number of outliers:  1379
# 		 0.008303639651845482
# 	Number of clusters:  8
# 	Number of outliers:  1085
# 		 0.0029240577346263405
# 	Number of clusters:  1
# 	Number of outliers:  917
# 		 0.01442262146936432
# 	Number of clusters:  1
# 	Number of outliers:  852
# 		 0.014831712919972704
# 	Number of clusters:  1
# 	Number of outliers:  831
# 		 0.014863692295505977
# 	Number of clusters:  1
# 	Number of outliers:  821
# 		 0.014843418564648384
# 	Number of clusters:  1
# 	Number of outliers:  818
# 		 0.014832260268751736
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.014822182208877637
#
# ----> MinPts 30
# 	Number of clusters:  1
# 	Number of outliers:  3617
# 		 -0.0019733498374089062
# 	Number of clusters:  2
# 	Number of outliers:  3334
# 		 -0.005080543549739588
# 	Number of clusters:  3
# 	Number of outliers:  3006
# 		 0.016959335014584267
# 	Number of clusters:  4
# 	Number of outliers:  2684
# 		 0.022948317781714085
# 	Number of clusters:  3
# 	Number of outliers:  2298
# 		 0.02392123736616531
# 	Number of clusters:  3
# 	Number of outliers:  1735
# 		 0.02813356877956017
# 	Number of clusters:  1
# 	Number of outliers:  1186
# 		 0.01518678691699812
# 	Number of clusters:  1
# 	Number of outliers:  917
# 		 0.015130683152720327
# 	Number of clusters:  1
# 	Number of outliers:  833
# 		 0.014896020254393363
# 	Number of clusters:  1
# 	Number of outliers:  819
# 		 0.014836865477742272
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.014822182208877637
#
#
# Working on S_path_dice
#
# ----> MinPts 2
# 	Number of clusters:  316
# 	Number of outliers:  1828
# 		 0.04774521469671327
# 	Number of clusters:  191
# 	Number of outliers:  1384
# 		 -0.027389166360514968
# 	Number of clusters:  56
# 	Number of outliers:  1025
# 		 -0.0431719814033412
# 	Number of clusters:  6
# 	Number of outliers:  876
# 		 0.014942671407162081
# 	Number of clusters:  5
# 	Number of outliers:  848
# 		 0.022586795832107757
# 	Number of clusters:  3
# 	Number of outliers:  829
# 		 0.023645924048933273
# 	Number of clusters:  2
# 	Number of outliers:  825
# 		 0.02385244497310252
# 	Number of clusters:  1
# 	Number of outliers:  823
# 		 0.02529079069463581
# 	Number of clusters:  1
# 	Number of outliers:  819
# 		 0.025264405615792563
# 	Number of clusters:  1
# 	Number of outliers:  818
# 		 0.025255698978359106
# 	Number of clusters:  1
# 	Number of outliers:  817
# 		 0.025247408071900516
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.025238616556041538
#
# ----> MinPts 3
# 	Number of clusters:  163
# 	Number of outliers:  2134
# 		 0.005936959443277639
# 	Number of clusters:  109
# 	Number of outliers:  1548
# 		 -0.02727087466233784
# 	Number of clusters:  31
# 	Number of outliers:  1075
# 		 -0.01444356270106364
# 	Number of clusters:  1
# 	Number of outliers:  886
# 		 0.024537659169920623
# 	Number of clusters:  1
# 	Number of outliers:  856
# 		 0.025198460744993444
# 	Number of clusters:  2
# 	Number of outliers:  831
# 		 0.025083751303379104
# 	Number of clusters:  1
# 	Number of outliers:  827
# 		 0.025316117587748356
# 	Number of clusters:  1
# 	Number of outliers:  823
# 		 0.02529079069463581
# 	Number of clusters:  1
# 	Number of outliers:  819
# 		 0.025264405615792563
# 	Number of clusters:  1
# 	Number of outliers:  818
# 		 0.025255698978359106
# 	Number of clusters:  1
# 	Number of outliers:  817
# 		 0.025247408071900516
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.025238616556041538
#
# ----> MinPts 5
# 	Number of clusters:  76
# 	Number of outliers:  2497
# 		 -0.022382747049608336
# 	Number of clusters:  50
# 	Number of outliers:  1845
# 		 -0.008352263945268515
# 	Number of clusters:  19
# 	Number of outliers:  1216
# 		 -0.00806509179134037
# 	Number of clusters:  1
# 	Number of outliers:  917
# 		 0.024418670260296697
# 	Number of clusters:  1
# 	Number of outliers:  872
# 		 0.025165321406073058
# 	Number of clusters:  1
# 	Number of outliers:  837
# 		 0.025294347408848113
# 	Number of clusters:  1
# 	Number of outliers:  828
# 		 0.025304134379771023
# 	Number of clusters:  1
# 	Number of outliers:  823
# 		 0.02529079069463581
# 	Number of clusters:  1
# 	Number of outliers:  819
# 		 0.025264405615792563
# 	Number of clusters:  1
# 	Number of outliers:  818
# 		 0.025255698978359106
# 	Number of clusters:  1
# 	Number of outliers:  817
# 		 0.025247408071900516
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.025238616556041538
#
# ----> MinPts 30
# 	Number of clusters:  2
# 	Number of outliers:  3405
# 		 -0.03150933486722767
# 	Number of clusters:  3
# 	Number of outliers:  3105
# 		 0.008950638324665304
# 	Number of clusters:  3
# 	Number of outliers:  2572
# 		 0.028288913274604775
# 	Number of clusters:  3
# 	Number of outliers:  1735
# 		 0.04537226364527587
# 	Number of clusters:  1
# 	Number of outliers:  1352
# 		 0.025836039454636507
# 	Number of clusters:  1
# 	Number of outliers:  1047
# 		 0.025792395272087272
# 	Number of clusters:  1
# 	Number of outliers:  877
# 		 0.025560328851950552
# 	Number of clusters:  1
# 	Number of outliers:  841
# 		 0.025418496795188816
# 	Number of clusters:  1
# 	Number of outliers:  826
# 		 0.025320232997512168
# 	Number of clusters:  1
# 	Number of outliers:  819
# 		 0.025263473861315916
# 	Number of clusters:  1
# 	Number of outliers:  817
# 		 0.025247408071900516
# 	Number of clusters:  1
# 	Number of outliers:  816
# 		 0.025238616556041538

# %%
# WRITING THE RESULTS IN FILES

print('Writing results combinations in files... ')

for m in ms_values:
    
    file_number_clust = open("results/" + directory_name + "Num_clusters_minsample" + str(m) + ".csv", "w")
    file_silhouette = open("results/" + directory_name + "Silhouette_coefficient_minsample" + str(m) + ".csv", "w")
       
    for e in epsilons:
    
        file_number_clust.write(str(e))
        file_silhouette.write(str(e))
    
        for met in sim_metrics:
        
            file_number_clust.write("," + str(n_clusters[e, m, met]))
            file_silhouette.write(",%.4f" %silh_coef[e, m, met])

        file_number_clust.write("\n")
        file_silhouette.write("\n")
        
    file_number_clust.close()
    file_silhouette.close()


print('\tDONE!')
# Out:
# Writing results combinations in files...
# 	DONE!
